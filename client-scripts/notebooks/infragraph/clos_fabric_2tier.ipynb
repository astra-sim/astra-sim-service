# %% [markdown]
# ##### Imports the necessary modules and sets the system path to locate them.

# %%
import sys
import networkx
import astra_sim_sdk.astra_sim_sdk as astra_sim_kit
sys.path.append("../../utils")
from astra_sim import AstraSim, Collective, NetworkBackend
from infragraph.infragraph_service import InfraGraphService
from infragraph.blueprints.fabrics.clos_fat_tree_fabric import ClosFatTreeFabric
from infragraph.blueprints.devices.server import Server
from infragraph.blueprints.devices.generic_switch import Switch

# %% [markdown]
# ##### Connects the client to the AstraSim gRPC server, initializes the AstraSim SDK, and creates a folder (tagged as specified) containing all configuration details, generated results, and logs.

# %%
astra = AstraSim(server_endpoint = "172.17.0.2:8989", tag = "infragraph_clos_2tier_trial")
# Out:
# Resetting test directory
# All contents of the folder /workspaces/astra_sim_service/client-scripts/utils/../trial/infragraph_clos_2tier_trial have been deleted.
# Successfully connected to gRPC server at 172.17.0.2:8989

# %% [markdown]
# ##### Creating Infragraph for 2 tier clos fabric

# %%
server = Server()
switch = Switch(port_count=8)
clos_fat_tree = ClosFatTreeFabric(switch, server, 2,[])
astra.configuration.infragraph.infrastructure.deserialize(clos_fat_tree.serialize())
print(astra.configuration.infragraph.infrastructure)
# Out:
# description: Clos Fat Tree Fabric
# devices:
# - components:
#   - choice: cpu
#     count: 1
#     description: Generic CPU
#     name: cpu
#   - choice: xpu
#     count: 2
#     description: Generic GPU/XPU
#     name: xpu
#   - choice: switch
#     count: 1
#     description: NVLink Switch
#     name: nvlsw
#   - choice: switch
#     count: 1
#     description: PCI Express Switch Gen 4
#     name: pciesw
#   - choice: nic
#     count: 2
#     description: Generic Nic
#     name: nic
#   - choice: custom
#     count: 1
#     custom:
#       type: mgmt-nic
#     description: Mgmt Nic
#     name: mgmt
#   description: A generic server with npu_factor * 4 xpu(s)
#   edges:
#   - ep1:
#       component: mgmt
#     ep2:
#       component: cpu[0]
#     link: pcie
#     scheme: one2one
#   - ep1:
#       component: cpu
#     ep2:
#       component: cpu
#     link: fabric
#     scheme: many2many
#   - ep1:
#       component: xpu
#     ep2:
#       component: nvlsw
#     link: nvlink
#     scheme: many2many
#   - ep1:
#       component: cpu[0]
#     ep2:
#       component: pciesw[0]
#     link: pcie
#     scheme: many2many
#   - ep1:
#       component: xpu[0:2]
#     ep2:
#       component: pciesw[0]
#     link: pcie
#     scheme: many2many
#   - ep1:
#       component: nic[0:2]
#     ep2:
#       component: pciesw[0]
#     link: pcie
#     scheme: many2many
#   links:
#   - description: CPU Fabric
#     name: fabric
#   - name: nvlink
#   - name: pcie
#   name: server
# - components:
#   - choice: cpu
#     count: 1
#     description: Generic ASIC
#     name: asic
#   - choice: port
#     count: 8
#     description: Generic port
#     name: port
#   description: A generic switch
#   edges:
#   - ep1:
#       component: asic
#     ep2:
#       component: port
#     link: ic
#     scheme: many2many
#   links:
#   - description: Generic integrated circuitry
#     name: ic
#   name: switch
# edges:
# - ep1:
#     component: nic[0]
#     instance: server[0]
#   ep2:
#     component: port[0]
#     instance: tier_0[0]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[1]
#     instance: server[0]
#   ep2:
#     component: port[1]
#     instance: tier_0[0]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[0]
#     instance: server[1]
#   ep2:
#     component: port[2]
#     instance: tier_0[0]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[1]
#     instance: server[1]
#   ep2:
#     component: port[3]
#     instance: tier_0[0]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[0]
#     instance: server[2]
#   ep2:
#     component: port[0]
#     instance: tier_0[1]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[1]
#     instance: server[2]
#   ep2:
#     component: port[1]
#     instance: tier_0[1]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[0]
#     instance: server[3]
#   ep2:
#     component: port[2]
#     instance: tier_0[1]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[1]
#     instance: server[3]
#   ep2:
#     component: port[3]
#     instance: tier_0[1]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[0]
#     instance: server[4]
#   ep2:
#     component: port[0]
#     instance: tier_0[2]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[1]
#     instance: server[4]
#   ep2:
#     component: port[1]
#     instance: tier_0[2]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[0]
#     instance: server[5]
#   ep2:
#     component: port[2]
#     instance: tier_0[2]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[1]
#     instance: server[5]
#   ep2:
#     component: port[3]
#     instance: tier_0[2]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[0]
#     instance: server[6]
#   ep2:
#     component: port[0]
#     instance: tier_0[3]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[1]
#     instance: server[6]
#   ep2:
#     component: port[1]
#     instance: tier_0[3]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[0]
#     instance: server[7]
#   ep2:
#     component: port[2]
#     instance: tier_0[3]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[1]
#     instance: server[7]
#   ep2:
#     component: port[3]
#     instance: tier_0[3]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[0]
#     instance: server[8]
#   ep2:
#     component: port[0]
#     instance: tier_0[4]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[1]
#     instance: server[8]
#   ep2:
#     component: port[1]
#     instance: tier_0[4]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[0]
#     instance: server[9]
#   ep2:
#     component: port[2]
#     instance: tier_0[4]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[1]
#     instance: server[9]
#   ep2:
#     component: port[3]
#     instance: tier_0[4]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[0]
#     instance: server[10]
#   ep2:
#     component: port[0]
#     instance: tier_0[5]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[1]
#     instance: server[10]
#   ep2:
#     component: port[1]
#     instance: tier_0[5]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[0]
#     instance: server[11]
#   ep2:
#     component: port[2]
#     instance: tier_0[5]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[1]
#     instance: server[11]
#   ep2:
#     component: port[3]
#     instance: tier_0[5]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[0]
#     instance: server[12]
#   ep2:
#     component: port[0]
#     instance: tier_0[6]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[1]
#     instance: server[12]
#   ep2:
#     component: port[1]
#     instance: tier_0[6]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[0]
#     instance: server[13]
#   ep2:
#     component: port[2]
#     instance: tier_0[6]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[1]
#     instance: server[13]
#   ep2:
#     component: port[3]
#     instance: tier_0[6]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[0]
#     instance: server[14]
#   ep2:
#     component: port[0]
#     instance: tier_0[7]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[1]
#     instance: server[14]
#   ep2:
#     component: port[1]
#     instance: tier_0[7]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[0]
#     instance: server[15]
#   ep2:
#     component: port[2]
#     instance: tier_0[7]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: nic[1]
#     instance: server[15]
#   ep2:
#     component: port[3]
#     instance: tier_0[7]
#   link: tier_0_link
#   scheme: one2one
# - ep1:
#     component: port[0]
#     instance: tier_1[0]
#   ep2:
#     component: port[4]
#     instance: tier_0[0]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[1]
#     instance: tier_1[0]
#   ep2:
#     component: port[4]
#     instance: tier_0[1]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[2]
#     instance: tier_1[0]
#   ep2:
#     component: port[4]
#     instance: tier_0[2]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[3]
#     instance: tier_1[0]
#   ep2:
#     component: port[4]
#     instance: tier_0[3]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[4]
#     instance: tier_1[0]
#   ep2:
#     component: port[4]
#     instance: tier_0[4]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[5]
#     instance: tier_1[0]
#   ep2:
#     component: port[4]
#     instance: tier_0[5]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[6]
#     instance: tier_1[0]
#   ep2:
#     component: port[4]
#     instance: tier_0[6]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[7]
#     instance: tier_1[0]
#   ep2:
#     component: port[4]
#     instance: tier_0[7]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[0]
#     instance: tier_1[1]
#   ep2:
#     component: port[5]
#     instance: tier_0[0]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[1]
#     instance: tier_1[1]
#   ep2:
#     component: port[5]
#     instance: tier_0[1]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[2]
#     instance: tier_1[1]
#   ep2:
#     component: port[5]
#     instance: tier_0[2]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[3]
#     instance: tier_1[1]
#   ep2:
#     component: port[5]
#     instance: tier_0[3]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[4]
#     instance: tier_1[1]
#   ep2:
#     component: port[5]
#     instance: tier_0[4]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[5]
#     instance: tier_1[1]
#   ep2:
#     component: port[5]
#     instance: tier_0[5]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[6]
#     instance: tier_1[1]
#   ep2:
#     component: port[5]
#     instance: tier_0[6]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[7]
#     instance: tier_1[1]
#   ep2:
#     component: port[5]
#     instance: tier_0[7]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[0]
#     instance: tier_1[2]
#   ep2:
#     component: port[6]
#     instance: tier_0[0]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[1]
#     instance: tier_1[2]
#   ep2:
#     component: port[6]
#     instance: tier_0[1]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[2]
#     instance: tier_1[2]
#   ep2:
#     component: port[6]
#     instance: tier_0[2]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[3]
#     instance: tier_1[2]
#   ep2:
#     component: port[6]
#     instance: tier_0[3]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[4]
#     instance: tier_1[2]
#   ep2:
#     component: port[6]
#     instance: tier_0[4]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[5]
#     instance: tier_1[2]
#   ep2:
#     component: port[6]
#     instance: tier_0[5]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[6]
#     instance: tier_1[2]
#   ep2:
#     component: port[6]
#     instance: tier_0[6]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[7]
#     instance: tier_1[2]
#   ep2:
#     component: port[6]
#     instance: tier_0[7]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[0]
#     instance: tier_1[3]
#   ep2:
#     component: port[7]
#     instance: tier_0[0]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[1]
#     instance: tier_1[3]
#   ep2:
#     component: port[7]
#     instance: tier_0[1]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[2]
#     instance: tier_1[3]
#   ep2:
#     component: port[7]
#     instance: tier_0[2]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[3]
#     instance: tier_1[3]
#   ep2:
#     component: port[7]
#     instance: tier_0[3]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[4]
#     instance: tier_1[3]
#   ep2:
#     component: port[7]
#     instance: tier_0[4]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[5]
#     instance: tier_1[3]
#   ep2:
#     component: port[7]
#     instance: tier_0[5]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[6]
#     instance: tier_1[3]
#   ep2:
#     component: port[7]
#     instance: tier_0[6]
#   link: tier_1_link
#   scheme: one2one
# - ep1:
#     component: port[7]
#     instance: tier_1[3]
#   ep2:
#     component: port[7]
#     instance: tier_0[7]
#   link: tier_1_link
#   scheme: one2one
# instances:
# - count: 16
#   device: server
#   name: server
# - count: 8
#   device: switch
#   name: tier_0
# - count: 4
#   device: switch
#   name: tier_1
# links:
# - description: Link characteristics for connectivity between host and tier 0 switches
#   name: tier_0_link
#   physical:
#     bandwidth:
#       choice: gigabits_per_second
#       gigabits_per_second: 100
# - description: Link characteristics for connectivity between tier 0 and tier 1 switches
#   name: tier_1_link
#   physical:
#     bandwidth:
#       choice: gigabits_per_second
#       gigabits_per_second: 200
# name: clos-fat-tree-fabric

# %% [markdown]
# ##### Display Fabric

# %%
service = InfraGraphService()
service.set_graph(clos_fat_tree)
g = service.get_networkx_graph()
print(networkx.write_network_text(g, vertical_chains=True))

total_npus = 32
# Out:
# ╙── server.11.mgmt.0
#     │
#     server.11.cpu.0
#     │
#     server.11.pciesw.0
#     ├── server.11.xpu.0
#     │   │
#     │   server.11.nvlsw.0
#     │   │
#     │   server.11.xpu.1 ─ server.11.pciesw.0
#     ├── server.11.nic.0
#     │   │
#     │   tier_0.5.port.2
#     │   │
#     │   tier_0.5.asic.0
#     │   ├── tier_0.5.port.0
#     │   │   │
#     │   │   server.10.nic.0
#     │   │   │
#     │   │   server.10.pciesw.0
#     │   │   ├── server.10.cpu.0
#     │   │   │   │
#     │   │   │   server.10.mgmt.0
#     │   │   ├── server.10.xpu.0
#     │   │   │   │
#     │   │   │   server.10.nvlsw.0
#     │   │   │   │
#     │   │   │   server.10.xpu.1 ─ server.10.pciesw.0
#     │   │   ├── server.10.nic.1
#     │   │   │   │
#     │   │   │   tier_0.5.port.1 ─ tier_0.5.asic.0
#     │   │   └──  ...
#     │   ├── tier_0.5.port.3
#     │   │   │
#     │   │   server.11.nic.1 ─ server.11.pciesw.0
#     │   ├── tier_0.5.port.4
#     │   │   │
#     │   │   tier_1.0.port.5
#     │   │   │
#     │   │   tier_1.0.asic.0
#     │   │   ├── tier_1.0.port.0
#     │   │   │   │
#     │   │   │   tier_0.0.port.4
#     │   │   │   │
#     │   │   │   tier_0.0.asic.0
#     │   │   │   ├── tier_0.0.port.0
#     │   │   │   │   │
#     │   │   │   │   server.0.nic.0
#     │   │   │   │   │
#     │   │   │   │   server.0.pciesw.0
#     │   │   │   │   ├── server.0.cpu.0
#     │   │   │   │   │   │
#     │   │   │   │   │   server.0.mgmt.0
#     │   │   │   │   ├── server.0.xpu.0
#     │   │   │   │   │   │
#     │   │   │   │   │   server.0.nvlsw.0
#     │   │   │   │   │   │
#     │   │   │   │   │   server.0.xpu.1 ─ server.0.pciesw.0
#     │   │   │   │   ├── server.0.nic.1
#     │   │   │   │   │   │
#     │   │   │   │   │   tier_0.0.port.1 ─ tier_0.0.asic.0
#     │   │   │   │   └──  ...
#     │   │   │   ├── tier_0.0.port.2
#     │   │   │   │   │
#     │   │   │   │   server.1.nic.0
#     │   │   │   │   │
#     │   │   │   │   server.1.pciesw.0
#     │   │   │   │   ├── server.1.cpu.0
#     │   │   │   │   │   │
#     │   │   │   │   │   server.1.mgmt.0
#     │   │   │   │   ├── server.1.xpu.0
#     │   │   │   │   │   │
#     │   │   │   │   │   server.1.nvlsw.0
#     │   │   │   │   │   │
#     │   │   │   │   │   server.1.xpu.1 ─ server.1.pciesw.0
#     │   │   │   │   ├── server.1.nic.1
#     │   │   │   │   │   │
#     │   │   │   │   │   tier_0.0.port.3 ─ tier_0.0.asic.0
#     │   │   │   │   └──  ...
#     │   │   │   ├── tier_0.0.port.5
#     │   │   │   │   │
#     │   │   │   │   tier_1.1.port.0
#     │   │   │   │   │
#     │   │   │   │   tier_1.1.asic.0
#     │   │   │   │   ├── tier_1.1.port.1
#     │   │   │   │   │   │
#     │   │   │   │   │   tier_0.1.port.5
#     │   │   │   │   │   │
#     │   │   │   │   │   tier_0.1.asic.0
#     │   │   │   │   │   ├── tier_0.1.port.0
#     │   │   │   │   │   │   │
#     │   │   │   │   │   │   server.2.nic.0
#     │   │   │   │   │   │   │
#     │   │   │   │   │   │   server.2.pciesw.0
#     │   │   │   │   │   │   ├── server.2.cpu.0
#     │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   server.2.mgmt.0
#     │   │   │   │   │   │   ├── server.2.xpu.0
#     │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   server.2.nvlsw.0
#     │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   server.2.xpu.1 ─ server.2.pciesw.0
#     │   │   │   │   │   │   ├── server.2.nic.1
#     │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   tier_0.1.port.1 ─ tier_0.1.asic.0
#     │   │   │   │   │   │   └──  ...
#     │   │   │   │   │   ├── tier_0.1.port.2
#     │   │   │   │   │   │   │
#     │   │   │   │   │   │   server.3.nic.0
#     │   │   │   │   │   │   │
#     │   │   │   │   │   │   server.3.pciesw.0
#     │   │   │   │   │   │   ├── server.3.cpu.0
#     │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   server.3.mgmt.0
#     │   │   │   │   │   │   ├── server.3.xpu.0
#     │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   server.3.nvlsw.0
#     │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   server.3.xpu.1 ─ server.3.pciesw.0
#     │   │   │   │   │   │   ├── server.3.nic.1
#     │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   tier_0.1.port.3 ─ tier_0.1.asic.0
#     │   │   │   │   │   │   └──  ...
#     │   │   │   │   │   ├── tier_0.1.port.4
#     │   │   │   │   │   │   │
#     │   │   │   │   │   │   tier_1.0.port.1 ─ tier_1.0.asic.0
#     │   │   │   │   │   ├── tier_0.1.port.6
#     │   │   │   │   │   │   │
#     │   │   │   │   │   │   tier_1.2.port.1
#     │   │   │   │   │   │   │
#     │   │   │   │   │   │   tier_1.2.asic.0
#     │   │   │   │   │   │   ├── tier_1.2.port.0
#     │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   tier_0.0.port.6 ─ tier_0.0.asic.0
#     │   │   │   │   │   │   ├── tier_1.2.port.2
#     │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   tier_0.2.port.6
#     │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   tier_0.2.asic.0
#     │   │   │   │   │   │   │   ├── tier_0.2.port.0
#     │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   server.4.nic.0
#     │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   server.4.pciesw.0
#     │   │   │   │   │   │   │   │   ├── server.4.cpu.0
#     │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   server.4.mgmt.0
#     │   │   │   │   │   │   │   │   ├── server.4.xpu.0
#     │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   server.4.nvlsw.0
#     │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   server.4.xpu.1 ─ server.4.pciesw.0
#     │   │   │   │   │   │   │   │   ├── server.4.nic.1
#     │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   tier_0.2.port.1 ─ tier_0.2.asic.0
#     │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │   │   │   ├── tier_0.2.port.2
#     │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   server.5.nic.0
#     │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   server.5.pciesw.0
#     │   │   │   │   │   │   │   │   ├── server.5.cpu.0
#     │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   server.5.mgmt.0
#     │   │   │   │   │   │   │   │   ├── server.5.xpu.0
#     │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   server.5.nvlsw.0
#     │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   server.5.xpu.1 ─ server.5.pciesw.0
#     │   │   │   │   │   │   │   │   ├── server.5.nic.1
#     │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   tier_0.2.port.3 ─ tier_0.2.asic.0
#     │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │   │   │   ├── tier_0.2.port.4
#     │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   tier_1.0.port.2 ─ tier_1.0.asic.0
#     │   │   │   │   │   │   │   ├── tier_0.2.port.5
#     │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   tier_1.1.port.2 ─ tier_1.1.asic.0
#     │   │   │   │   │   │   │   ├── tier_0.2.port.7
#     │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   tier_1.3.port.2
#     │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   tier_1.3.asic.0
#     │   │   │   │   │   │   │   │   ├── tier_1.3.port.0
#     │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   tier_0.0.port.7 ─ tier_0.0.asic.0
#     │   │   │   │   │   │   │   │   ├── tier_1.3.port.1
#     │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   tier_0.1.port.7 ─ tier_0.1.asic.0
#     │   │   │   │   │   │   │   │   ├── tier_1.3.port.3
#     │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   tier_0.3.port.7
#     │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   tier_0.3.asic.0
#     │   │   │   │   │   │   │   │   │   ├── tier_0.3.port.0
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   server.6.nic.0
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   server.6.pciesw.0
#     │   │   │   │   │   │   │   │   │   │   ├── server.6.cpu.0
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   server.6.mgmt.0
#     │   │   │   │   │   │   │   │   │   │   ├── server.6.xpu.0
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   server.6.nvlsw.0
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   server.6.xpu.1 ─ server.6.pciesw.0
#     │   │   │   │   │   │   │   │   │   │   ├── server.6.nic.1
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   tier_0.3.port.1 ─ tier_0.3.asic.0
#     │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │   │   │   │   │   ├── tier_0.3.port.2
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   server.7.nic.0
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   server.7.pciesw.0
#     │   │   │   │   │   │   │   │   │   │   ├── server.7.cpu.0
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   server.7.mgmt.0
#     │   │   │   │   │   │   │   │   │   │   ├── server.7.xpu.0
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   server.7.nvlsw.0
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   server.7.xpu.1 ─ server.7.pciesw.0
#     │   │   │   │   │   │   │   │   │   │   ├── server.7.nic.1
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   tier_0.3.port.3 ─ tier_0.3.asic.0
#     │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │   │   │   │   │   ├── tier_0.3.port.4
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   tier_1.0.port.3 ─ tier_1.0.asic.0
#     │   │   │   │   │   │   │   │   │   ├── tier_0.3.port.5
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   tier_1.1.port.3 ─ tier_1.1.asic.0
#     │   │   │   │   │   │   │   │   │   ├── tier_0.3.port.6
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   tier_1.2.port.3 ─ tier_1.2.asic.0
#     │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │   │   │   │   ├── tier_1.3.port.4
#     │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   tier_0.4.port.7
#     │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   tier_0.4.asic.0
#     │   │   │   │   │   │   │   │   │   ├── tier_0.4.port.0
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   server.8.nic.0
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   server.8.pciesw.0
#     │   │   │   │   │   │   │   │   │   │   ├── server.8.cpu.0
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   server.8.mgmt.0
#     │   │   │   │   │   │   │   │   │   │   ├── server.8.xpu.0
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   server.8.nvlsw.0
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   server.8.xpu.1 ─ server.8.pciesw.0
#     │   │   │   │   │   │   │   │   │   │   ├── server.8.nic.1
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   tier_0.4.port.1 ─ tier_0.4.asic.0
#     │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │   │   │   │   │   ├── tier_0.4.port.2
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   server.9.nic.0
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   server.9.pciesw.0
#     │   │   │   │   │   │   │   │   │   │   ├── server.9.cpu.0
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   server.9.mgmt.0
#     │   │   │   │   │   │   │   │   │   │   ├── server.9.xpu.0
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   server.9.nvlsw.0
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   server.9.xpu.1 ─ server.9.pciesw.0
#     │   │   │   │   │   │   │   │   │   │   ├── server.9.nic.1
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   tier_0.4.port.3 ─ tier_0.4.asic.0
#     │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │   │   │   │   │   ├── tier_0.4.port.4
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   tier_1.0.port.4 ─ tier_1.0.asic.0
#     │   │   │   │   │   │   │   │   │   ├── tier_0.4.port.5
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   tier_1.1.port.4 ─ tier_1.1.asic.0
#     │   │   │   │   │   │   │   │   │   ├── tier_0.4.port.6
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   tier_1.2.port.4 ─ tier_1.2.asic.0
#     │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │   │   │   │   ├── tier_1.3.port.5
#     │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   tier_0.5.port.7 ─ tier_0.5.asic.0
#     │   │   │   │   │   │   │   │   ├── tier_1.3.port.6
#     │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   tier_0.6.port.7
#     │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   tier_0.6.asic.0
#     │   │   │   │   │   │   │   │   │   ├── tier_0.6.port.0
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   server.12.nic.0
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   server.12.pciesw.0
#     │   │   │   │   │   │   │   │   │   │   ├── server.12.cpu.0
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   server.12.mgmt.0
#     │   │   │   │   │   │   │   │   │   │   ├── server.12.xpu.0
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   server.12.nvlsw.0
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   server.12.xpu.1 ─ server.12.pciesw.0
#     │   │   │   │   │   │   │   │   │   │   ├── server.12.nic.1
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   tier_0.6.port.1 ─ tier_0.6.asic.0
#     │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │   │   │   │   │   ├── tier_0.6.port.2
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   server.13.nic.0
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   server.13.pciesw.0
#     │   │   │   │   │   │   │   │   │   │   ├── server.13.cpu.0
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   server.13.mgmt.0
#     │   │   │   │   │   │   │   │   │   │   ├── server.13.xpu.0
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   server.13.nvlsw.0
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   server.13.xpu.1 ─ server.13.pciesw.0
#     │   │   │   │   │   │   │   │   │   │   ├── server.13.nic.1
#     │   │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   │   tier_0.6.port.3 ─ tier_0.6.asic.0
#     │   │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │   │   │   │   │   ├── tier_0.6.port.4
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   tier_1.0.port.6 ─ tier_1.0.asic.0
#     │   │   │   │   │   │   │   │   │   ├── tier_0.6.port.5
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   tier_1.1.port.6 ─ tier_1.1.asic.0
#     │   │   │   │   │   │   │   │   │   ├── tier_0.6.port.6
#     │   │   │   │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   │   │   │   tier_1.2.port.6 ─ tier_1.2.asic.0
#     │   │   │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │   │   │   │   └── tier_1.3.port.7
#     │   │   │   │   │   │   │   │       │
#     │   │   │   │   │   │   │   │       tier_0.7.port.7
#     │   │   │   │   │   │   │   │       │
#     │   │   │   │   │   │   │   │       tier_0.7.asic.0
#     │   │   │   │   │   │   │   │       ├── tier_0.7.port.0
#     │   │   │   │   │   │   │   │       │   │
#     │   │   │   │   │   │   │   │       │   server.14.nic.0
#     │   │   │   │   │   │   │   │       │   │
#     │   │   │   │   │   │   │   │       │   server.14.pciesw.0
#     │   │   │   │   │   │   │   │       │   ├── server.14.cpu.0
#     │   │   │   │   │   │   │   │       │   │   │
#     │   │   │   │   │   │   │   │       │   │   server.14.mgmt.0
#     │   │   │   │   │   │   │   │       │   ├── server.14.xpu.0
#     │   │   │   │   │   │   │   │       │   │   │
#     │   │   │   │   │   │   │   │       │   │   server.14.nvlsw.0
#     │   │   │   │   │   │   │   │       │   │   │
#     │   │   │   │   │   │   │   │       │   │   server.14.xpu.1 ─ server.14.pciesw.0
#     │   │   │   │   │   │   │   │       │   ├── server.14.nic.1
#     │   │   │   │   │   │   │   │       │   │   │
#     │   │   │   │   │   │   │   │       │   │   tier_0.7.port.1 ─ tier_0.7.asic.0
#     │   │   │   │   │   │   │   │       │   └──  ...
#     │   │   │   │   │   │   │   │       ├── tier_0.7.port.2
#     │   │   │   │   │   │   │   │       │   │
#     │   │   │   │   │   │   │   │       │   server.15.nic.0
#     │   │   │   │   │   │   │   │       │   │
#     │   │   │   │   │   │   │   │       │   server.15.pciesw.0
#     │   │   │   │   │   │   │   │       │   ├── server.15.cpu.0
#     │   │   │   │   │   │   │   │       │   │   │
#     │   │   │   │   │   │   │   │       │   │   server.15.mgmt.0
#     │   │   │   │   │   │   │   │       │   ├── server.15.xpu.0
#     │   │   │   │   │   │   │   │       │   │   │
#     │   │   │   │   │   │   │   │       │   │   server.15.nvlsw.0
#     │   │   │   │   │   │   │   │       │   │   │
#     │   │   │   │   │   │   │   │       │   │   server.15.xpu.1 ─ server.15.pciesw.0
#     │   │   │   │   │   │   │   │       │   ├── server.15.nic.1
#     │   │   │   │   │   │   │   │       │   │   │
#     │   │   │   │   │   │   │   │       │   │   tier_0.7.port.3 ─ tier_0.7.asic.0
#     │   │   │   │   │   │   │   │       │   └──  ...
#     │   │   │   │   │   │   │   │       ├── tier_0.7.port.4
#     │   │   │   │   │   │   │   │       │   │
#     │   │   │   │   │   │   │   │       │   tier_1.0.port.7 ─ tier_1.0.asic.0
#     │   │   │   │   │   │   │   │       ├── tier_0.7.port.5
#     │   │   │   │   │   │   │   │       │   │
#     │   │   │   │   │   │   │   │       │   tier_1.1.port.7 ─ tier_1.1.asic.0
#     │   │   │   │   │   │   │   │       ├── tier_0.7.port.6
#     │   │   │   │   │   │   │   │       │   │
#     │   │   │   │   │   │   │   │       │   tier_1.2.port.7 ─ tier_1.2.asic.0
#     │   │   │   │   │   │   │   │       └──  ...
#     │   │   │   │   │   │   │   └──  ...
#     │   │   │   │   │   │   ├── tier_1.2.port.5
#     │   │   │   │   │   │   │   │
#     │   │   │   │   │   │   │   tier_0.5.port.6 ─ tier_0.5.asic.0
#     │   │   │   │   │   │   └──  ...
#     │   │   │   │   │   └──  ...
#     │   │   │   │   ├── tier_1.1.port.5
#     │   │   │   │   │   │
#     │   │   │   │   │   tier_0.5.port.5 ─ tier_0.5.asic.0
#     │   │   │   │   └──  ...
#     │   │   │   └──  ...
#     │   │   └──  ...
#     │   └──  ...
#     └──  ...
# None

# %% [markdown]
# ##### Generates workload execution traces for each rank and configures the data size, which is mandatory for AstraSim workload configuration.

# %%
astra.configuration.common_config.workload = astra.generate_collective(collective=Collective.ALLREDUCE, coll_size= 8 *1024*1024, npu_range=[0, total_npus])
# Out:
# Generated 32 et in /workspaces/astra_sim_service/client-scripts/utils/../trial/infragraph_clos_2tier_trial/configuration/workload

# %% [markdown]
# ##### Configure the system configurations

# %%
astra.configuration.common_config.system.scheduling_policy = astra.configuration.common_config.system.LIFO
astra.configuration.common_config.system.endpoint_delay = 10
astra.configuration.common_config.system.active_chunks_per_dimension = 1
astra.configuration.common_config.system.all_gather_implementation = [astra.configuration.common_config.system.RING]
astra.configuration.common_config.system.all_to_all_implementation = [astra.configuration.common_config.system.DIRECT]
astra.configuration.common_config.system.all_reduce_implementation = [astra.configuration.common_config.system.ONERING]
astra.configuration.common_config.system.collective_optimization = astra.configuration.common_config.system.LOCALBWAWARE
astra.configuration.common_config.system.local_mem_bw = 1600

# %% [markdown]
# ##### Configure the remote memory configuration

# %%
astra.configuration.common_config.remote_memory.memory_type = astra.configuration.common_config.remote_memory.NO_MEMORY_EXPANSION
print(astra.configuration.common_config.remote_memory)
# Out:
# memory_type: NO_MEMORY_EXPANSION
# remote_mem_bw: 0
# remote_mem_latency: 0

# %% [markdown]
# ##### Configure the network backend choice and the topology choice for that backend

# %%
astra.configuration.network_backend.choice = astra.configuration.network_backend.NS3
astra.configuration.network_backend.ns3.topology.choice = astra.configuration.network_backend.ns3.topology.INFRAGRAPH
astra.configuration.network_backend.ns3.network.packet_payload_size = int(8192)

# %% [markdown]
# ##### Adding ns3 trace and logical dimension

# %%
astra.configuration.network_backend.ns3.logical_topology.logical_dimensions = [total_npus]
astra.configuration.network_backend.ns3.trace.trace_ids = []
for i in range(0, total_npus):
    astra.configuration.network_backend.ns3.trace.trace_ids.append(i)

# %% [markdown]
# ##### Adding ASTRA-sim specific annotation

# %%
host_device_spec = astra_sim_kit.AnnotationDeviceSpecifications()
host_device_spec.device_bandwidth_gbps = 100
host_device_spec.device_latency_ms = 0.05
host_device_spec.device_name = "server"
host_device_spec.device_type = "host"
astra.configuration.infragraph.annotations.device_specifications.append(host_device_spec)

switch_device_spec = astra_sim_kit.AnnotationDeviceSpecifications()
switch_device_spec.device_bandwidth_gbps = 100
switch_device_spec.device_latency_ms = 0.05
switch_device_spec.device_name = "switch"
switch_device_spec.device_type = "switch"
astra.configuration.infragraph.annotations.device_specifications.append(
    switch_device_spec
)

# %% [markdown]
# ##### Configure ASTRA-sim cmd parameters

# %%
astra.configuration.common_config.cmd_parameters.comm_scale = 1
astra.configuration.common_config.cmd_parameters.injection_scale = 1
astra.configuration.common_config.cmd_parameters.rendezvous_protocol = False

# %% [markdown]
# #### Start the simulation by providing the network backend name in uppercase letters.

# %%
astra.run_simulation(NetworkBackend.NS3)
# Out:
# Generating Configuration ZIP
# output_path: /workspaces/astra_sim_service/client-scripts/utils/../trial/infragraph_clos_2tier_trial/config.zip
# folder_path: /workspaces/astra_sim_service/client-scripts/utils/../trial/infragraph_clos_2tier_trial/configuration
# message: 'Configuration applied successfully. warnings: Unable to generate communicator
#   group message from schema - communicator group configuration empty'
#
# message: Simulation started successfully
#
# astra-sim server Status: running
# astra-sim server Status: running
# astra-sim server Status: running
# astra-sim server Status: running
# astra-sim server Status: running
# Downloading Output files....
# Transferring Files from ASTRA-sim server
# Downloading file: fct.txt
# Downloading file: flow.txt
# Downloading file: pfc.txt
# Downloading file: qlen.txt
# Downloading file: simulation.log
# Downloading file: trace_out.tr
# All files downloaded Successfully
# Translating Metrics...
# Generated fct.csv at:  /workspaces/astra_sim_service/client-scripts/utils/../trial/infragraph_clos_2tier_trial/output/fct.csv
# Generated: flow_stats.csv at:  /workspaces/astra_sim_service/client-scripts/utils/../trial/infragraph_clos_2tier_trial/output/flow_stats.csv
# All metrics translated successfully
# Simulation completed
# /workspaces/astra_sim_service/client-scripts/notebooks/infragraph/../../utils/common.py:274: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(
# /workspaces/astra_sim_service/client-scripts/notebooks/infragraph/../../utils/common.py:237: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(

# %% [markdown]
# ##### Download all the configurations as a zip

# %%
astra.download_configuration()
# Out:
# Downloaded all configuration in /workspaces/astra_sim_service/client-scripts/utils/../trial/infragraph_clos_2tier_trial/server_configuration.zip

# %% [markdown]
# ##### Read output files

# %%
import pandas as pd
import os
from common import FileFolderUtils
df = pd.read_csv(os.path.join(FileFolderUtils.get_instance().OUTPUT_DIR, "fct.csv"))
df.head()
# Out:
#   Source Hex ip Destination Hex ip  Source Port  Destination Port  \
# 0      0b000201           0b000301        10000               100
# 1      0b000601           0b000701        10000               100
# 2      0b000a01           0b000b01        10000               100
# 3      0b000e01           0b000f01        10000               100
# 4      0b001001           0b001101        10000               100
#
#    Data size (B)  Start Time    FCT  Standalone FCT
# 0         262144          10  41722           42404
# 1         262144          10  41722           42404
# 2         262144          10  41722           42404
# 3         262144          10  41722           42404
# 4         262144          10  41722           42404

# %%
df = pd.read_csv(os.path.join(FileFolderUtils.get_instance().OUTPUT_DIR, "flow_stats.csv"))
df.head()
# Out:
#    Source ip Destination ip  Source Port  Destination Port  Data size (B)  \
# 0   11.0.2.1       11.0.3.1        10000               100         262144
# 1   11.0.6.1       11.0.7.1        10000               100         262144
# 2  11.0.10.1      11.0.11.1        10000               100         262144
# 3  11.0.14.1      11.0.15.1        10000               100         262144
# 4  11.0.16.1      11.0.17.1        10000               100         262144
#
#    Start Time    FCT  Standalone FCT  Total Bytes Tx  Total Bytes Rx  \
# 0          10  41722           42404          262144          262144
# 1          10  41722           42404          262144          262144
# 2          10  41722           42404          262144          262144
# 3          10  41722           42404          262144          262144
# 4          10  41722           42404          262144          262144
#
#    Completion time (ms)  Start (ms)  End (ms)
# 0              0.041722     0.00001  0.041732
# 1              0.041722     0.00001  0.041732
# 2              0.041722     0.00001  0.041732
# 3              0.041722     0.00001  0.041732
# 4              0.041722     0.00001  0.041732

# %% [markdown]
# ##### Save infragraph as a yaml

# %%
import yaml
with open(os.path.join(FileFolderUtils.get_instance().OUTPUT_DIR,"../infrastructure","2tier.yaml"),"w") as f:
    data = clos_fat_tree.serialize("dict")
    yaml.dump(data, f, default_flow_style=False, indent=4)

print("saved yaml to:", os.path.join(FileFolderUtils.get_instance().OUTPUT_DIR,"..","2tier.yaml"))
# Out:
# saved yaml to: /workspaces/astra_sim_service/client-scripts/utils/../trial/infragraph_clos_2tier_trial/output/../2tier.yaml
